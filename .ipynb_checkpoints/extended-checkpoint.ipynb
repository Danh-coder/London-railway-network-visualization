# %% [markdown]
# # 1. Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx

# %% [markdown]
# # 2. Read dataset

# %%
df = pd.read_csv('London_transport_network.csv').dropna()
df.head()
# Out:
#         Line   Direction     Station from (A)    Station to (B)  \
# 0  Bakerloo   Southbound  HARROW & WEALDSTONE            KENTON
# 1  Bakerloo   Southbound               KENTON      SOUTH KENTON
# 2  Bakerloo   Southbound         SOUTH KENTON     NORTH WEMBLEY
# 3  Bakerloo   Southbound        NORTH WEMBLEY   WEMBLEY CENTRAL
# 4  Bakerloo   Southbound      WEMBLEY CENTRAL  STONEBRIDGE PARK
#
#    Distance (Kms)  Un-impeded Running Time (Mins)  \
# 0            1.74                            2.23
# 1            1.40                            1.88
# 2            0.90                            1.50
# 3            1.27                            1.92
# 4            1.71                            2.23
#
#    AM peak (0700-1000) Running Time (Mins)  \
# 0                                     2.50
# 1                                     2.00
# 2                                     1.50
# 3                                     2.06
# 4                                     3.13
#
#    Inter peak (1000 - 1600) Running time (mins)
# 0                                          2.50
# 1                                          2.00
# 2                                          1.50
# 3                                          2.06
# 4                                          3.13

# %%
df1 = pd.read_csv('London stations.csv').dropna()
df1.head()
# Out:
#            Station    OS X    OS Y   Latitude  Longitude Zone Postcode
# 0       Abbey Road  539081  183352  51.531952   0.003723    3  E15 3NB
# 1       Abbey Wood  547297  179002  51.490784   0.120272    4  SE2 9RH
# 2    Acton Central  520613  180299  51.508757  -0.263430    2   W3 6BH
# 3  Acton Main Line  520296  181196  51.516886  -0.267690    3   W3 9EH
# 4       Acton Town  519457  179639  51.503071  -0.280303    3   W3 8HN

# %% [markdown]
# # 2. Understanding Data

# %% [markdown]
# # 3. Preprocessing
# This section will:
# <br>
# <b>Capitalize the stations name</b>
# <br>
# <b>Remove . </b> after St. in df1
# <br>
# <b>Remove ' </b> in df1
# <br>
# <b>Remove (...) </b> in df
# <br>
# <b>Remove (...) </b> in df1
# <br>
# <b>Replace "-" with " " </b> in df1
# <br>
# <b>Replace "and " with & </b> in df1
# <br>
# <b>Heathrow 123, Heathrow Terminal Four: </b> add the word "Terminal" and space between numbers in df <br>
# <b>Walthamstow, Highbury: </b> change the name to Walthamstow Central and Highbury & Islington in df <br>

# %% [markdown]
# ## 3.1. Capitalize stations name

# %%
df['Station from (A)'] = df['Station from (A)'].str.title()
df['Station to (B)'] = df['Station to (B)'].str.title()
df.head()
# Out:
#         Line   Direction     Station from (A)    Station to (B)  \
# 0  Bakerloo   Southbound  Harrow & Wealdstone            Kenton
# 1  Bakerloo   Southbound               Kenton      South Kenton
# 2  Bakerloo   Southbound         South Kenton     North Wembley
# 3  Bakerloo   Southbound        North Wembley   Wembley Central
# 4  Bakerloo   Southbound      Wembley Central  Stonebridge Park
#
#    Distance (Kms)  Un-impeded Running Time (Mins)  \
# 0            1.74                            2.23
# 1            1.40                            1.88
# 2            0.90                            1.50
# 3            1.27                            1.92
# 4            1.71                            2.23
#
#    AM peak (0700-1000) Running Time (Mins)  \
# 0                                     2.50
# 1                                     2.00
# 2                                     1.50
# 3                                     2.06
# 4                                     3.13
#
#    Inter peak (1000 - 1600) Running time (mins)
# 0                                          2.50
# 1                                          2.00
# 2                                          1.50
# 3                                          2.06
# 4                                          3.13

# %% [markdown]
# ## 3.2. Remove "." after "St"

# %%
df1['Station'] = df1['Station'].str.replace('St.', 'St')
df1[df1['Station'].str.contains('St.')]
# Out:
#                      Station    OS X    OS Y   Latitude  Longitude     Zone  \
# 23              Baker Street  527965  182078  51.523129  -0.156904        1
# 36   Battersea Power Station  529122  177252  51.479496  -0.142001        1
# 63               Bond Street  528497  181053  51.513797  -0.149614        1
# 96             Cannon Street  532623  180888  51.511362  -0.090251        1
# 127            Church Street  532041  165555  51.373706  -0.104347  3,4,5,6
# 130      Clapham High Street  529824  175709  51.465469  -0.132465        2
# 212         Fenchurch Street  533434  180932  51.511567  -0.078554        1
# 224            George Street  532432  165594  51.373966  -0.098718  3,4,5,6
# 230            Goodge Street  529505  181837  51.520613  -0.134808        1
# 237    Great Portland Street  528861  182174  51.523789  -0.143961        1
# 280   High Street Kensington  525622  179527  51.500729  -0.191566        1
# 323   Kings Cross St Pancras  530236  182935  51.530312  -0.123872        1
# 346         Liverpool Street  533160  181596  51.517598  -0.082250        1
# 416               Old Street  532764  182474  51.525581  -0.087623        1
# 485   Shoreditch High Street  533501  182258  51.523467  -0.077087        1
# 488            Silver Street  533544  192472  51.615242  -0.072590        4
# 513                St Helier  525408  167191  51.389912  -0.199015        4
# 514          St James Street  536402  188694  51.580609  -0.032805        3
# 515                 St Johns  537400  176298  51.468975  -0.023241        2
# 516             St Margarets  516732  174250  51.455205  -0.321324        4
# 517             St Mary Cray  546698  168298  51.394760   0.107218        6
# 518               St Pancras  530122  182959  51.530554  -0.125506        1
# 519          St James's Park  529629  179503  51.499610  -0.133879        1
# 520            St Johns Wood  526742  183352  51.534854  -0.174065        2
# 521                 St Pauls  532105  181261  51.514835  -0.097571        1
# 522           Stamford Brook  521913  178738  51.494450  -0.245246        2
# 523            Stamford Hill  533381  187928  51.574447  -0.076668        3
# 524                 Stanmore  517574  192569  51.619673  -0.303099        5
# 525                Star Lane  539148  182091  51.520604   0.004191        3
# 526            Stepney Green  535566  182149  51.521996  -0.047383        2
# 527                Stockwell  530473  176470  51.472159  -0.122846        2
# 528          Stoke Newington  533710  186845  51.564637  -0.072335        2
# 529         Stonebridge Park  519690  184197  51.543986  -0.275400        3
# 530               Stoneleigh  522021  164155  51.363364  -0.248710        5
# 531                Stratford  538533  184421  51.541693  -0.003752        3
# 532    Stratford High Street  538729  184032  51.538149  -0.001080        3
# 533  Stratford International  538175  184758  51.544809  -0.008778        3
# 534          Strawberry Hill  515500  172502  51.439747  -0.339618        5
# 535                Streatham  529946  171303  51.425846  -0.132325        3
# 536         Streatham Common  529729  170534  51.418984  -0.135726        3
# 537           Streatham Hill  530233  172714  51.438460  -0.127681        3
# 573            Turkey Street  535129  198903  51.672654  -0.047230        6
# 600            Warren Street  529253  182272  51.524580  -0.138278        1
# 605      Watford High Street  511360  196098  51.652653  -0.391697        8
# 611          Wembley Stadium  518924  185366  51.554654  -0.286046        4
# 648              Wood Street  538521  189426  51.586670  -0.001954        4
#
#      Postcode
# 23    NW1 5LA
# 36   SW11 8AL
# 63    W1C 2HU
# 96   EC4N 6AP
# 127   CR0 1RN
# 130   SW4 6DQ
# 212  EC3M 4AJ
# 224   CRO 1LA
# 230   W1T 2HF
# 237   W1W 5PP
# 280    W8 5SA
# 323    N1 9AL
# 346  EC2M 7PR
# 416  EC1V 9NR
# 485    E1 6AW
# 488   N18 1QX
# 513   SM4 6SF
# 514   E17 7PJ
# 515   SE8 4EW
# 516   TW1 2LH
# 517   BR5 3SN
# 518   NW1 2QP
# 519  SW1H 0BD
# 520   NW8 6DN
# 521  EC2V 6AA
# 522    W6 0SB
# 523   N16 5AG
# 524   HA7 4PD
# 525   E16 4SR
# 526    E1 4AQ
# 527   SW9 9AE
# 528   N16 6YA
# 529  NW10 0RW
# 530  KT17 2JA
# 531   E15 1AZ
# 532   E15 3PA
# 533   E15 2LZ
# 534   TW1 4PP
# 535  SW16 6HP
# 536  SW16 5NT
# 537   SW2 4PA
# 573   EN3 5TT
# 600   NW1 3AA
# 605  WD17 2EG
# 611   HA9 8BQ
# 648   E17 3NZ

# %% [markdown]
# ## 3.3. Remove " ' "

# %%
df1['Station'] = df1['Station'].str.replace("'", "")
df1[df1['Station'].str.contains("King")]
df1[df1['Station'].str.contains("Jame")]
# Out:
#              Station    OS X    OS Y   Latitude  Longitude Zone  Postcode
# 514  St James Street  536402  188694  51.580609  -0.032805    3   E17 7PJ
# 519   St Jamess Park  529629  179503  51.499610  -0.133879    1  SW1H 0BD

# %% [markdown]
# ## 3.4. Remove (...)

# %%
df1['Station'] = df1['Station'].str.replace(r'\s*\(.*?\)\s*', '', regex=True)
df['Station from (A)'] = df['Station from (A)'].str.replace(r'\s*\(.*?\)\s*', '', regex=True)
df['Station to (B)'] = df['Station to (B)'].str.replace(r'\s*\(.*?\)\s*', '', regex=True)

df1[df1['Station'].str.contains("Baker")]
df[df['Station from (A)'].str.contains("Baker")]
df[df['Station to (B)'].str.contains("Baker")]
# Out:
#              Line   Direction       Station from (A) Station to (B)  \
# 15      Bakerloo   Southbound             Marylebone   Baker Street
# 31      Bakerloo   Northbound           Regents Park   Baker Street
# 190      Jubilee    Eastbound          St Johns Wood   Baker Street
# 216      Jubilee    Westbound            Bond Street   Baker Street
# 438  Metropolitan   Westbound  Great Portland Street   Baker Street
# 492  Metropolitan   Eastbound          Finchley Road   Baker Street
# 509         H & C   Eastbound           Edgware Road  Baker Street
# 545         H & C   Westbound  Great Portland Street  Baker Street
# 580       Circle        Inner  Great Portland Street   Baker Street
# 582       Circle        Outer           Edgware Road  Baker Street
#
#      Distance (Kms)  Un-impeded Running Time (Mins)  \
# 15             0.50                            1.17
# 31             0.88                            1.65
# 190            2.06                            2.77
# 216            1.66                            2.28
# 438            0.92                            2.23
# 492            3.38                            6.13
# 509            0.72                            1.47
# 545            0.92                            1.57
# 580            0.92                            1.57
# 582            0.72                            1.47
#
#      AM peak (0700-1000) Running Time (Mins)  \
# 15                                      1.50
# 31                                      2.00
# 190                                     3.50
# 216                                     2.50
# 438                                     4.08
# 492                                     7.11
# 509                                     2.84
# 545                                     2.90
# 580                                     2.90
# 582                                     2.84
#
#      Inter peak (1000 - 1600) Running time (mins)
# 15                                           1.50
# 31                                           2.00
# 190                                          3.50
# 216                                          2.50
# 438                                          3.82
# 492                                          6.40
# 509                                          2.50
# 545                                          2.07
# 580                                          2.07
# 582                                          2.50

# %% [markdown]
# ## 3.5. Correct some station names

# %%
# Replace specific substrings in 'Station from (A)' and 'Station to (B)'
df['Station from (A)'] = df['Station from (A)'].replace({
    'Harrow-On-The-Hill': 'Harrow-on-the-Hill',
    'Bromley By Bow': 'Bromley-by-Bow',
    'Heathrow 123': 'Heathrow Terminals 1 2 3',
    'Heathrow Terminal Four': 'Heathrow Terminal 4',
    'Walthamstow': 'Walthamstow Central',
    'Highbury': 'Highbury & Islington',
    'Shoreditch': 'Shoreditch High Street'
})

df['Station to (B)'] = df['Station to (B)'].replace({
    'Harrow-On-The-Hill': 'Harrow-on-the-Hill',
    'Bromley By Bow': 'Bromley-by-Bow',
    'Heathrow 123': 'Heathrow Terminals 1 2 3',
    'Heathrow Terminal Four': 'Heathrow Terminal 4',
    'Walthamstow': 'Walthamstow Central',
    'Highbury': 'Highbury & Islington',
    'Shoreditch': 'Shoreditch High Street'
})

df1['Station'] = df1['Station'].str.replace('Jamess', 'James')

df[df['Station from (A)'].str.contains('Harrow')]
df[df['Station from (A)'].str.contains('Bromley')]
df1[df1['Station'].str.contains('James')]
# Out:
#              Station    OS X    OS Y   Latitude  Longitude Zone  Postcode
# 514  St James Street  536402  188694  51.580609  -0.032805    3   E17 7PJ
# 519    St James Park  529629  179503  51.499610  -0.133879    1  SW1H 0BD

# %% [markdown]
# ## 3.6. Replace "and" with "&"

# %%
# Replace occurrences of "and" with "&" in 'Station from (A)' and 'Station to (B)'
df1['Station'] = df1['Station'].str.replace(r'\band\b', '&', regex=True)
df1['Station'] = df1['Station'].str.replace(r'\band\b', '&', regex=True)

df1[df1['Station'].str.contains('&')]
# Out:
#                          Station    OS X    OS Y   Latitude  Longitude Zone  \
# 89   Caledonian Road & Barnsbury  530800  184393  51.543284  -0.115205    2
# 109           Chalfont & Latimer  499610  197550  51.667907  -0.561068    8
# 147  Crossharbour & London Arena  537896  179301  51.495840  -0.014933    2
# 187            Elephant & Castle  531940  179144  51.495849  -0.100739  1,2
# 191        Elstree & Borehamwood  519098  196299  51.652875  -0.279829    6
# 216      Finchley Road & Frognal  526035  185033  51.550119  -0.183651    2
# 264          Harrow & Wealdstone  515486  189508  51.592594  -0.334253    5
# 270           Hayes & Harlington  509717  179417  51.503048  -0.420642    5
# 282         Highbury & Islington  531562  184770  51.546495  -0.104082    2
# 538        Sudbury & Harrow Road  516853  185300  51.554493  -0.315926    4
# 568       Totteridge & Whetstone  526111  193951  51.630246  -0.179354    4
#
#     Postcode
# 89    N1 0SL
# 109  HP7 9PR
# 147  E14 8AD
# 187  SE1 6LW
# 191  WD6 3LS
# 216  NW3 5HT
# 264  HA3 7RF
# 270  UB3 4BX
# 282   N1 1SE
# 538  HA0 2HA
# 568  N20 9QP

# %% [markdown]
# ## 3.7. Extract stations to a new DataFrame

# %%
# Trim station names the last time
df['Station from (A)'] = df['Station from (A)'].str.strip()
df['Station to (B)'] = df['Station to (B)'].str.strip()
df1['Station'] = df1['Station'].str.strip()

# %%
df_stations = pd.DataFrame(pd.concat([df['Station from (A)'], df['Station to (B)']]).unique(), columns=['Name'])
df_stations
# Out:
#                        Name
# 0       Harrow & Wealdstone
# 1                    Kenton
# 2              South Kenton
# 3             North Wembley
# 4           Wembley Central
# ..                      ...
# 267            Surrey Quays
# 268             Rotherhithe
# 269                 Wapping
# 270                Shadwell
# 271  Shoreditch High Street
#
# [272 rows x 1 columns]

# %% [markdown]
# Merge the location dataset with the stations dataset

# %%
df_stations_1 = df_stations.merge(df1, left_on='Name', right_on='Station', how='left')
df_stations_1
# Out:
#                        Name                 Station    OS X    OS Y  \
# 0       Harrow & Wealdstone     Harrow & Wealdstone  515486  189508
# 1                    Kenton                  Kenton  516833  188304
# 2              South Kenton            South Kenton  517350  187153
# 3             North Wembley           North Wembley  517663  186198
# 4           Wembley Central         Wembley Central  518214  185039
# ..                      ...                     ...     ...     ...
# 269            Surrey Quays            Surrey Quays  535641  178954
# 270             Rotherhithe             Rotherhithe  535239  179870
# 271                 Wapping                 Wapping  535030  180170
# 272                Shadwell                Shadwell  534936  180942
# 273  Shoreditch High Street  Shoreditch High Street  533501  182258
#
#       Latitude  Longitude Zone  Postcode
# 0    51.592594  -0.334253    5   HA3 7RF
# 1    51.581496  -0.315217    4   HA3 0XS
# 2    51.571044  -0.308143    4   HA9 8QT
# 3    51.562396  -0.303948    4   HA0 3NT
# 4    51.551864  -0.296392    4   HA9 6AG
# ..         ...        ...  ...       ...
# 269  51.493267  -0.047530    2  SE16 2UE
# 270  51.501594  -0.052966    2  SE16 4LF
# 271  51.504340  -0.055861    2   E1W 3PA
# 272  51.511300  -0.056919    2    E1 2QE
# 273  51.523467  -0.077087    1    E1 6AW
#
# [274 rows x 8 columns]

# %%
df_stations_1[df_stations_1['Station'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Station, OS X, OS Y, Latitude, Longitude, Zone, Postcode]
# Index: []

# %%
df1[df1['Station'].str.contains('Edgware', na=False) & (df1['Station'].str.len() > len('Edgware'))]
# Out:
#           Station    OS X    OS Y   Latitude  Longitude Zone Postcode
# 184  Edgware Road  527026  181778  51.520645  -0.170540    1   W2 1DY
# 185  Edgware Road  527227  181711  51.519998  -0.167668    1  NW1 5DH

# %% [markdown]
# Conclusion: After merging, there are some missing stations, but in fact, they have locations values but <b>the names are different</b>, for example, Edgware Road.
# <br>
# So I have to <b>analyze</b> both datasets to identify <b>general</b> methods to clean data

# %% [markdown]
# <b>Solution 1:</b> Use the first word and check whether it is in a row of the df1 dataset

# %%
for index, row in df_stations_1[df_stations_1['Station'].isnull()].iterrows():
    first_station_name = row['Name'].split(' ')[0]
    # Check if there are any matching stations in df1
    matching_stations = df1[df1['Station'].str.contains(first_station_name, na=False)]
    
    for _, row1 in matching_stations.iterrows():
        matching_station_name = row1['Station'].split(' ')[0]
        if matching_station_name == first_station_name and len(row1['Station']) > len(first_station_name):
            print(row['Name'], '- ', row1['Station'])
            # break
    
    # if not matching_stations.empty:
    #     print(row['Name'], ' - ', matching_stations.iloc[0]['Station'])

# %%
# df[df['Station from (A)'].str.contains('Baker')]
df1[df1['Station'].str.contains('Baker')]
# print(df[df['Station from (A)'].str.contains('Jame')], df1[df1['Station'].str.contains('Jame')])
# Out:
#          Station    OS X    OS Y   Latitude  Longitude Zone Postcode
# 23  Baker Street  527965  182078  51.523129  -0.156904    1  NW1 5LA

# %% [markdown]
# <b>Conclusion:</b>
# <br>
# St Pauls/...: remove . after St. in df1 <br>
# Kings Cross: Remove ' in df1 <br>
# Euston (CX), Euston (City): Remove (...) in df_stations_1 <br>
# Edgware Road: Remove (...) in df1 <br>
# Bromley By Bow: replace "-" with " " in df1 <br>
# Elephant & Castle: replace "and " with & in df1 <br>
# Heathrow 123, Heathrow Terminal Four: add the word "Terminal" and space between numbers in df_stations_1 <br>
# Walthamstow, Highbury: change the name to Walthamstow Central and Highbury & Islington in df_stations_1 <br>

# %% [markdown]
# ## 3.8. Extract lines to a new DataFrame

# %%
# Trim station lines the last time
df['Line'] = df['Line'].str.strip()

df_lines = pd.DataFrame(df['Line'].str.strip().unique(), columns=['Line']) # Trim whitespaces
df_lines
# Out:
#                Line
# 0          Bakerloo
# 1           Central
# 2          Victoria
# 3   Waterloo & City
# 4           Jubilee
# 5          Northern
# 6        Piccadilly
# 7      Metropolitan
# 8             H & C
# 9            Circle
# 10         District
# 11      East London

# %% [markdown]
# # 4. Exploratory Analysis, Explanatory Analysis (Done)

# %% [markdown]
# # 5. Feature Engineering
# This section will do several actions:
# 1. Style colors for the lines and add it to the DataFrame
# 2. Remove unnecessary columns

# %% [markdown]
# ## 5.1. Style colors for the lines and add it to the DataFrame

# %% [markdown]
# Line colors get from https://assets.nationalrail.co.uk/e8xgegruud3g/15WiPgTRPGTuEUQC4dDJDv/367cc30c505e9c45b759c0fa57627648/London_Rail___Tube_Map_December_2023.pdf and http://www.railwaycodes.org.uk/line/track/distances/undergrounddistances.pdf

# %%
colors = {
    'Bakerloo': 'brown',
    'Central': 'red',
    'Victoria': '#6EACDA',
    'Waterloo & City': '#9CDBA6',
    'Jubilee': 'grey',
    'Northern': 'black',
    'Piccadilly': 'blue',
    'Metropolitan': 'purple',
    'H & C': 'pink',
    'Circle': 'yellow',
    'District': 'green',
    'East London': 'orange',
}

# %%
df_lines['Color'] = df_lines['Line'].map(colors)
df_lines
# Out:
#                Line    Color
# 0          Bakerloo    brown
# 1           Central      red
# 2          Victoria  #6EACDA
# 3   Waterloo & City  #9CDBA6
# 4           Jubilee     grey
# 5          Northern    black
# 6        Piccadilly     blue
# 7      Metropolitan   purple
# 8             H & C     pink
# 9            Circle   yellow
# 10         District    green
# 11      East London   orange

# %% [markdown]
# ## 5.2. Remove unnecessary columns

# %%
df.drop(["Un-impeded Running Time (Mins)", "AM peak (0700-1000) Running Time (Mins)", "Inter peak (1000 - 1600) Running time (mins)", "Direction"], axis=1, inplace=True)
df
# Out:
#             Line     Station from (A)    Station to (B)  Distance (Kms)
# 0       Bakerloo  Harrow & Wealdstone            Kenton            1.74
# 1       Bakerloo               Kenton      South Kenton            1.40
# 2       Bakerloo         South Kenton     North Wembley            0.90
# 3       Bakerloo        North Wembley   Wembley Central            1.27
# 4       Bakerloo      Wembley Central  Stonebridge Park            1.71
# ..           ...                  ...               ...             ...
# 738  East London              Wapping       Rotherhithe            0.51
# 739  East London          Rotherhithe      Canada Water            0.32
# 740  East London         Canada Water      Surrey Quays            0.55
# 741  East London         Surrey Quays         New Cross            2.27
# 742  East London         Surrey Quays    New Cross Gate            2.04
#
# [743 rows x 4 columns]

# %%
df_stations_1.drop(['Name', 'OS X', 'OS Y', 'Zone', 'Postcode'], axis=1, inplace=True)
df_stations_1
# Out:
#                     Station   Latitude  Longitude
# 0       Harrow & Wealdstone  51.592594  -0.334253
# 1                    Kenton  51.581496  -0.315217
# 2              South Kenton  51.571044  -0.308143
# 3             North Wembley  51.562396  -0.303948
# 4           Wembley Central  51.551864  -0.296392
# ..                      ...        ...        ...
# 269            Surrey Quays  51.493267  -0.047530
# 270             Rotherhithe  51.501594  -0.052966
# 271                 Wapping  51.504340  -0.055861
# 272                Shadwell  51.511300  -0.056919
# 273  Shoreditch High Street  51.523467  -0.077087
#
# [274 rows x 3 columns]

# %% [markdown]
# # 6. Data Visualization

# %%
def draw_network(stations = df_stations_1, edges = df, lines = df_lines, figsize=(60, 20)):
    MyGraph = nx.Graph()
    
    # Add nodes
    for index, row in stations.iterrows():
        MyGraph.add_node(row['Station'], npos=(row['Longitude'], row['Latitude']), color='white', border='black')
    
    # Add edges
    for index, row in edges.iterrows():
        first_line = row['Line']
        line_color = df_lines[df_lines['Line'] == first_line]['Color'].values[0]
        MyGraph.add_edge(row['Station from (A)'], row['Station to (B)'], weight=row['Distance (Kms)'], color=line_color)
        
    # Extract attributes from the graph to dictionaries
    pos = nx.get_node_attributes(MyGraph, 'npos')
    nodecolor = nx.get_node_attributes(MyGraph, 'color')
    edgecolor = nx.get_edge_attributes(MyGraph, 'color')
    edgeweight = nx.get_edge_attributes(MyGraph, 'weight')
    
    # Place the values from the dictionaries in lists
    NodeList = list(nodecolor.values())
    EdgeList = list(edgecolor.values())
    
    # Draw the graph's nodes and edges
    plt.figure(figsize=figsize)
    nx.draw_networkx_nodes(MyGraph, pos=pos, node_color=NodeList)
    nx.draw_networkx_edges(MyGraph, pos=pos, edge_color=EdgeList)
    nx.draw_networkx_edge_labels(MyGraph, pos=pos, edge_labels=edgeweight, font_size=15)
    
    # Display the name of the stations
    for index, row in stations.iterrows():
        name = row['Station']
        if name == "Tottenham Court Road":
            name = "Tottenham\nCourt Road"  # Wrap the text
        elif name == "Covent Garden":
            name = "Covent\nGarden" # Wrap the text           
        plt.text(row['Longitude'], row['Latitude'], name, rotation=15, ha='center', va='center', fontsize=15)
    
    # Draw legend
    for index, row in lines.iterrows():
        plt.plot([], [], color=row['Color'], label=row['Line'], linewidth=2)
    legend = plt.legend(loc='lower right', fontsize=12, frameon=True, framealpha=1, borderpad=1, prop={'size':15})
    legend.get_frame().set_linewidth(2)
    
    # Set legend font color
    for index, row in lines.iterrows():
        legend.get_texts()[index].set_color(row['Color'])
    
    # Add "Key" text above the legend
    legend_bbox = legend.get_window_extent().transformed(plt.gca().transData.inverted())
    plt.text((legend_bbox.x0 + legend_bbox.x1) / 2, legend_bbox.y1 + 0.005, "Key", fontsize=15, ha='center', va='center', weight='bold')
    
    # Visualize the graph
    plt.title('Public Transport Network of London', fontsize=30, fontweight='bold')
    plt.grid(axis='x', alpha=0)
    plt.grid(axis='y', alpha=0)
    plt.show()

draw_network()

# %%
# Get the line color for the first row in df_edges
first_line = df.iloc[0]['Line']
line_color = df_lines[df_lines['Line'] == first_line]['Color'].values[0]
print('+' + line_color + '+')
# Out:
# +brown+

# %%
df_lines
# Out:
#                Line    Color
# 0          Bakerloo    brown
# 1           Central      red
# 2          Victoria  #6EACDA
# 3   Waterloo & City  #9CDBA6
# 4           Jubilee     grey
# 5          Northern    black
# 6        Piccadilly     blue
# 7      Metropolitan   purple
# 8             H & C     pink
# 9            Circle   yellow
# 10         District    green
# 11      East London   orange

# %%
import pandas as pd
import networkx as nx
import plotly.graph_objects as go

def draw_network(stations, edges, lines, figsize=(10, 10)):
    MyGraph = nx.Graph()
    
    # Add nodes
    for index, row in stations.iterrows():
        MyGraph.add_node(row['Station'], npos=(row['Longitude'], row['Latitude']), color='black', border='black')
    
    # Add edges
    for index, row in edges.iterrows():
        first_line = row['Line']
        line_color = df_lines[df_lines['Line'] == first_line]['Color'].values[0]
        MyGraph.add_edge(row['Station from (A)'], row['Station to (B)'], weight=row['Distance (Kms)'], color=line_color)
        
    # Extract attributes from the graph to dictionaries
    pos = nx.get_node_attributes(MyGraph, 'npos')
    edgecolor = nx.get_edge_attributes(MyGraph, 'color')
    edgeweight = nx.get_edge_attributes(MyGraph, 'weight')

    # Create edge traces
    edge_trace = []
    for edge in MyGraph.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        color = edge[2]['color']
        weight = edge[2]['weight']
        edge_trace.append(
            go.Scatter(
                x=[x0, x1, None],
                y=[y0, y1, None],
                line=dict(width=weight, color=color),
                hoverinfo='none',
                mode='lines'
            )
        )

    # Create node traces
    node_trace = go.Scatter(
        x=[pos[node][0] for node in MyGraph.nodes()],
        y=[pos[node][1] for node in MyGraph.nodes()],
        text=[node for node in MyGraph.nodes()],
        mode='markers+text',
        textposition='top center',
        marker=dict(size=10, color='black'),
        hoverinfo='text'
    )

    # Create plot layout
    layout = go.Layout(
        title='Public Transport Network of London',
        titlefont_size=30,
        showlegend=False,
        hovermode='closest',
        margin=dict(b=20, l=5, r=5, t=40),
        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        height=figsize[1] * 100,  # Scale the figure size appropriately
        width=figsize[0] * 100
    )

    # Create figure
    fig = go.Figure(data=edge_trace + [node_trace], layout=layout)

    # Display the figure
    fig.show()

# Sample usage with assumed DataFrames
draw_network(df_stations_1, df, df_lines)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_network(stations=df_stations_1, edges=df, lines=df_lines, figsize=(60, 20)):
    MyGraph = nx.Graph()
    
    # Add nodes
    for index, row in stations.iterrows():
        MyGraph.add_node(row['Station'], pos=(row['Longitude'], row['Latitude']), color='white', border='black')
    
    # Add edges
    for index, row in edges.iterrows():
        first_line = row['Line']
        line_color = df_lines[df_lines['Line'] == first_line]['Color'].values[0]
        MyGraph.add_edge(row['Station from (A)'], row['Station to (B)'], weight=row['Distance (Kms)'], color=line_color)
        
    # Extract attributes from the graph to dictionaries
    pos = nx.get_node_attributes(MyGraph, 'pos')
    edgecolor = nx.get_edge_attributes(MyGraph, 'color')
    edgeweight = nx.get_edge_attributes(MyGraph, 'weight')
    
    # Place the values from the dictionaries in lists
    nodecolor = nx.get_node_attributes(MyGraph, 'color').values()
    edgecolors = list(edgecolor.values())
    
    # Draw the graph's nodes and edges
    plt.figure(figsize=figsize)
    nx.draw(MyGraph, pos, with_labels=True, node_color=nodecolor, edge_color=edgecolors, node_size=300, font_size=10, font_color='black', font_weight='bold', edge_cmap=plt.cm.Blues)
    
    # Draw edge labels
    edge_labels = {edge: f'{edgeweight[edge]:.2f} km' for edge in MyGraph.edges}
    nx.draw_networkx_edge_labels(MyGraph, pos, edge_labels=edge_labels, font_size=10)
    
    # Draw legend
    for index, row in lines.iterrows():
        plt.plot([], [], color=row['Color'], label=row['Line'], linewidth=2)
    legend = plt.legend(loc='upper left', fontsize=12, frameon=True, framealpha=1, borderpad=1, prop={'size':15})
    legend.get_frame().set_linewidth(2)
    
    # Set legend font color
    for index, row in lines.iterrows():
        legend.get_texts()[index].set_color(row['Color'])
    
    # Add "Key" text above the legend
    legend_bbox = legend.get_window_extent().transformed(plt.gca().transData.inverted())
    plt.text((legend_bbox.x0 + legend_bbox.x1) / 2, legend_bbox.y1 + 0.005, "Key", fontsize=15, ha='center', va='center', weight='bold')
    
    # Set title
    plt.title('Public Transport Network of London', fontsize=30, fontweight='bold')
    
    # Show plot
    plt.show()

# Sample usage with assumed DataFrames
draw_network(df_stations_1, df, df_lines)
